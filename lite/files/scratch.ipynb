# %% [markdown]
# Run the two cells below, then write TLA⁺ in the cell after them — a cell starting with `---- MODULE Name ----` is a spec, a cell of `SPECIFICATION` / `CONSTANT` / `INVARIANT` lines checks it, and anything else is ordinary Python.
#
# No tutorial here on purpose. There is one in [`tla-in-your-browser.ipynb`](/lab/index.html?path=tla-in-your-browser.ipynb) if you want it.

# %%
# %pip install -q tlakit

# %%
# %load_ext tlakit

import tlakit
from tlakit.magics import MODULES
